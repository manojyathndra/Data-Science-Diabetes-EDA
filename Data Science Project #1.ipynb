# %%
#!/usr/bin/env python
# coding: utf-8

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(filepath_or_buffer="https://web.stanford.edu/~hastie/Papers/LARS/diabetes.data",sep="\t")
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
#missing values
print(df.isnull().sum())
# Out:
# AGE    0
# SEX    0
# BMI    0
# BP     0
# S1     0
# S2     0
# S3     0
# S4     0
# S5     0
# S6     0
# Y      0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(x="variable",y="value",data=pd.melt(df))
plt.show()

# %%
sns.boxplot(df['AGE'])
plt.show()

# %%
sns.boxplot(df['SEX'])
plt.show()

# %%
sns.boxplot(df['BMI'])
plt.show()

# %%
sns.boxplot(df['BP'])
plt.show()

# %%
sns.boxplot(df['S1'])
plt.show()

# %%
sns.boxplot(df['S2'])
plt.show()

# %%
sns.boxplot(df['S3'])
plt.show()

# %%
sns.boxplot(df['S4'])
plt.show()

# %%
sns.boxplot(df['S5'])
plt.show()

# %%
sns.boxplot(df['S6'])
plt.show()

# %%
sns.boxplot(df['Y'])
plt.show()

# %%
#outliers remove

for i in range(0,10):
    

    q1=df.iloc[:,i].quantile(.25)
    q3=df.iloc[:,i].quantile(.75)
    iqr=q3-q1
    low=q1-1.5*iqr
    high=q3+1.5*iqr

    df.iloc[:,i]=np.where(df.iloc[:,i]<low,low,df.iloc[:,i])
    df.iloc[:,i]=np.where(df.iloc[:,i]>high,high,df.iloc[:,i])

# %% [markdown]
# There are several factors to consider in the data cleaning process.
#
# Duplicate or irrelevant observations.
#
# Bad labeling of data, same category occurring multiple times.
#
# Missing or null data points.
#
# Unexpected outliers.

# %%
df
# Out:
#       AGE  SEX   BMI      BP     S1     S2    S3    S4       S5       S6    Y
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.85980   87.000  151
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.89180   69.000   75
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.67280   85.000  141
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.89030   89.000  206
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.29050   80.000  135
# 5    23.0  1.0  22.6   89.00  139.0   64.8  61.0  2.00  4.18970   68.000   97
# 6    36.0  2.0  22.0   90.00  160.0   99.6  50.0  3.00  3.95120   82.000  138
# 7    66.0  2.0  26.2  114.00  255.0  185.0  56.0  4.55  4.24850   92.000   63
# 8    60.0  2.0  32.1   83.00  179.0  119.4  42.0  4.00  4.47730   94.000  110
# 9    29.0  1.0  30.0   85.00  180.0   93.4  43.0  4.00  5.38450   88.000  310
# 10   22.0  1.0  18.6   97.00  114.0   57.6  46.0  2.00  3.95120   83.000  101
# ...

# %%
import seaborn as sns
a4_dims = (8, 6)
fig, ax = plt.subplots(figsize=a4_dims)
sns.boxplot(x="variable",y="value",data=pd.melt(df))

plt.show()

# %%
df.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.358965   94.647014  188.986425  115.213857
# std     13.109028    0.499561    4.365892   13.831283   34.172164   29.715466
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   38.387500  133.000000  278.000000  192.175000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.643665    4.067149    4.641183   91.228790  152.133484
# std     12.476566    1.279829    0.521757   11.346132   77.093005
# ...

# %% [markdown]
# The describe() function computes a summary of statistics pertaining to the DataFrame columns.

# %%
#Transforming data
df['BMI']=pd.to_numeric(df['BMI'])

# %%
#data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
# AGE    442 non-null float64
# SEX    442 non-null float64
# BMI    442 non-null float64
# BP     442 non-null float64
# S1     442 non-null float64
# S2     442 non-null float64
# S3     442 non-null float64
# S4     442 non-null float64
# S5     442 non-null float64
# S6     442 non-null float64
# Y      442 non-null int64
# dtypes: float64(10), int64(1)
# memory usage: 38.1 KB

# %%
df.corr()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# AGE  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# SEX  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# BMI  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# BP   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# S1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# S2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# S3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# S4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# S5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# S6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            S4        S5        S6         Y
# ...

# %% [markdown]
# Here used the corr() function on the pandas DataFrames to calculate a correlation matrix.
#
# For calclation correlation co-efficient is used.
#
# co-efficient assumes a normal distribution of the attributes involved. a co relation if -1 to 1 shows the positive or negative corolation respectivly.
#
# on other hand zero represent no relation.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, ax=ax)
plt.show()

# %% [markdown]
# In, above heat map, brighten colour indicates more corelation.
#
# As, we can see from the table heat map BMI(0.59) is more related followed by S5(0.57) and AGE,BP,SEX, and Serum all have significant corelation with the outcome variable.
#
# Also, notice the correlation between the pairs of features.

# %%
#limitation
df.shape
# Out:
# (442, 11)

# %% [markdown]
# Above value shows that small dataset.
#
# S1-S6 Unknown
#
# Outliers may effect the op
